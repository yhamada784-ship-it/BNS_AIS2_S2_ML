# %%
print("sdnj")

# %%
name="123ax22"
if name==123 :
    print("cinm")
elif name==1158:
    print("cismcim")
else:
    print("mksdmkcm")

# %%
i=1
while i<=5 :
    print(i)
    i+=1

# %%
i=1
while i<=10 :
    i+=1
    if i==8 :
        continue
    else :
        print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 9
# 10
# 11

# %%
select_answer ="cairo"
answer =""
while select_answer !=answer :
     answer =input ("what is the secret anaswer ?")
     if answer == select_answer :
          print("correct answer")
     else :
          print("please enter the corect answer")
# Out:
# please enter the corect answer
# please enter the corect answer
# please enter the corect answer
# please enter the corect answer
# correct answer

# %%
correct_answer ="Yousef Hamada"
answer =""
i = 0
while correct_answer != answer and i<=3:
    answer = input("what is your name ?").title()
    if answer == correct_answer:
        print("correct answer")
    else:
        print("please enter the correct answer")
        i+=1
        if i==4:
            print("end limet")
# Out:
# please enter the correct answer
# please enter the correct answer
# correct answer

# %%
corect_answer =5
enter_number = int(input("Guess the number between 1 to 10 :"))
while enter_number != corect_answer :

    if enter_number>corect_answer :
          
        print("too high")

        enter_number = int(input("Guess again :"))
    
    elif enter_number<corect_answer:
    
        print("too low")
    
        enter_number = int(input("Guess again :"))

print("correct answer")
# Out:
# correct answer

# %%
name= "yousef"
for x in name :
    print(f"this letter is {x.upper()}")
# Out:
# this letter is Y
# this letter is O
# this letter is U
# this letter is S
# this letter is E
# this letter is F

# %%
colors =["red","blue","green","yellow"]
for i in colors :
    if i=="blue" :
        print(f"my favoiret color : {i}")
    else:
        print(i)
# Out:
# red
# my favoiret color : blue
# green
# yellow
