# %%
email = "Amit_ml@gmail.edu"
at_position = email.index("@")
username = email[0:at_position]
rest = email[at_position + 1:]
is_valid = email.count("@") == 1 and "." in rest
dot_position = rest.rindex(".")
domain = rest[0:dot_position]
ending = rest[dot_position + 1:]
domain_type = (ending == "com") and "Commercial Domain" or (ending == "edu") and "Educational Domain" or "Other Domain"
print("Username:", username)
print("Domain:", domain)
print("Type:", domain_type)
# Out:
# Username: Amit_ml
# Domain: gmail
# Type: Educational Domain

# %%
#Task2
encoded_message = "###!!@mocleW EPGTQ!!!6789"
extract=encoded_message.strip("!@#6789")
world1,world2=extract.split()
decoded_world1=world1[::-1]
decoded_world2=world2.replace("E","")
print(f"{decoded_world1} {decoded_world2}")
# Out:
# Welcom PGTQ

# %%
#Task3
encoded_message = "&&&**$gnirts PLIO!!@1234"
extract=encoded_message.strip("&*$!@1234")
world1,world2=extract.split()
decoded_world1=world1[::-1]
decoded_world2=world2.replace("I","E").replace("O","U")
print(f"{decoded_world1} {decoded_world2}")
# Out:
# string PLEU

# %%
#Task4
encoded_message = "##$$$@!yalpstcejorp EPUVT*****9887"
extract=encoded_message.strip("#$@!*987")
world1,world2=extract.split()
decoded_world1=world1[::-1].replace("s","")
decoded_world2=world2.replace("E","A").replace("U","O")
print(f"{decoded_world1} {decoded_world2.replace("OVT","TOV")}")
# Out:
# projectplay APTOV
