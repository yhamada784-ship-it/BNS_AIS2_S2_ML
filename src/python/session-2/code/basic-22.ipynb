# %%
list1=[1,2,3,4,"depi","learning",["ml","DL","GenAI"]]
type(list1)
# Out:
# list

# %%
list_one=["depi","learning","python"]
list_one.append("ML")
print(list_one)
# Out:
# ['depi', 'learning', 'python', 'ML']

# %%
list_one=["depi","learning","python"]
list_one.insert(1,"data anaalsis")
list_one.insert(2,2)
list_one
# Out:
# ['depi', 'data anaalsis', 2, 'learning', 'python']

# %%
list_one=["depi","learning","python"]
new_list =list_one + ["machine"]
print(list_one)
print(new_list)
# Out:
# ['depi', 'learning', 'python']
# ['depi', 'learning', 'python', 'machine']

# %%
list_one=["depi","learning","python"]
list_one.remove("depi")
list_one
# Out:
# ['learning', 'python']

# %%
list_one=["depi","learning","python"]
list_one.pop(0)
list_one
# Out:
# ['learning', 'python']

# %%
list_1=["Depi","nti","iti"]
new_list =[]
task_1=list_1.pop()
new_list.append(task_1)
print(list_1)
print(new_list)
# Out:
# ['Depi', 'nti']
# ['iti']

# %%
list_1.clear()
list_1
# Out:
# []

# %%
input_list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]

item = input("Enter the item you want to remove: ")

input_list.remove(item)

print(input_list)
# Out:
# ['amit', 'learning', 'machine learning', 'data science', 'deep learning']

# %%
tuple_one =("depi","learning","python")

# %%
chatbot ={
"hello":"hello how can i help you",
"python":"python is a programming language",
"ai":"ai is a technology",
}
print(chatbot.keys())
# Out:
# dict_keys(['hello', 'python', 'ai'])

# %%
question = input("Enter your question: ").lower()
print(chatbot.get(question,"I am sorry I don't understand your question"))
# Out:
# I am sorry I don't understand your question
